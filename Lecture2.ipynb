# %% [markdown]
# Heart Alvern Sumicad

# %% [markdown]
# ### Task 1 Answers:
# #### Question 1:
#
# We aim to show that the expected value of the sum $Y$ (repeated trials) equals $n \cdot p_i$, where:
#
# * $n$ is the number of trials
# * $p_i$ is the probability of success in each trial
#
# **Step 1: Expected Value of a Single Trial (Y_i)**
#
# The expected value of a single trial ($Y_i$) is calculated by summing the possible outcomes ($y_i$) weighted by their probabilities ($P(Y_i = y_i)$):
#
# $$E[Y_i] = \sum_{y_i} y_i \cdot P(Y_i = y_i)$$
#
# **Step 2: Probability of Each Outcome (Y_i)**
#
# Since each trial follows a binomial distribution, the probability of getting a specific outcome ($y_i$) is:
#
# * $\binom{n}{y_i}$ (number of ways to get $y_i$ successes in $n$ trials)
# * $p_i^{y_i}$ (probability of success in each trial raised to the power of successes)
# * $(1 - p_i)^{n - y_i}$ (probability of failure raised to the power of failures)
#
# **Step 3: Expected Value of a Single Trial (Formula)**
#
# Combining the probability and outcome for each possible value of $Y_i$, we get the formula for the expected value of a single trial:
#
# $$E[Y_i] = \sum_{y_i} y_i \cdot \binom{n}{y_i} p_i^{y_i} (1 - p_i)^{n - y_i}$$
#
# **Step 4: Expected Value of a Single Trial (Result)**
#
# This formula is known to evaluate to $n \cdot p_i$ for a binomial distribution. Therefore, for each trial ($Y_i$), the expected value is $E[Y_i] = n \cdot p_i$.
#
# **Step 5: Expected Value of the Sum (Y)**
#
# Since the trials ($Y_1, Y_2, ..., Y_k$) are independent (outcomes don't affect each other), the expected value of their sum ($Y$) is simply the sum of their individual expected values.
#
# **Step 6: Expected Value of the Sum (Formula)**
#
# The expected value of the sum ($Y$) is:
#
# $$E[Y] = E[Y_1] + E[Y_2] + ... + E[Y_k]$$
#
# **Step 7: Expected Value of the Sum (Result)**
#
# Substituting the known expected value for each trial ($n \cdot p_i$):
#
# $$E[Y] = n \cdot p_1 + n \cdot p_2 + ... + n \cdot p_k$$
#
# Factoring out $n$, we get:
#
# $$E[Y] = n \cdot (p_1 + p_2 + ... + p_k)$$
#
# Since the sum of probabilities for all possible outcomes in a trial is always 1, this simplifies to:
#
# $$E[Y] = n \cdot 1 = n$$
#
# **Conclusion:**
#
# Therefore, the expected value of the sum of independent Bernoulli trials ($Y$) is indeed $n \cdot p_i$.
# \end{proof}
#
#
#
# ### Question 2:
#
# Given the data:
#
#
# \begin{align*}
# \text{Age} & \quad \text{Proportion} \\
# 18-24 & \quad 0.18 \\
# 25-34 & \quad 0.23 \\
# 35-44 & \quad 0.16 \\
# 45-64 & \quad 0.27 \\
# 65-100 & \quad 0.16 \\
# \end{align*}
#
#
# If 500 adults are sampled randomly, we want to find the probability that the sample contains 100 persons between 18 and 24, 200 between 25 and 34, and 200 between 45 and 64.
#
#
# The multinomial probability formula will be used to calculate this probability. It considers the sample size ($n$), the number of individuals in each age group within the sample ($y_i$), and the population proportion for each age group ($p_i$).
#
# **Multinomial Probability Formula:**
#
# The multinomial probability formula is:
#
# $$P(y_1, y_2, y_3, y_4, y_5) = \frac{n!}{y_1!y_2!y_3!y_4!y_5!} \cdot p_1^{y_1} p_2^{y_2} p_3^{y_3} p_4^{y_4} p_5^{y_5}$$
#
# where:
#
# * $n$ is the total sample size (500 in this case)
# * $y_i$ is the number of individuals in the $i$th age group (e.g., $y_1 = 100$ for 18-24)
# * $p_i$ is the proportion of individuals in the $i$th age group (e.g., $p_1 = 0.18$ for 18-24)
#
# **Expected Value for Specific Age Group:**
#
# The expected number of individuals in a specific age group (e.g., 65 and above) can be found by multiplying the total sample size ($n$) by the proportion of the population in that age group ($p_5$).
#
# **Example: Expected Value for 65 and Above**
#
# $$E[y_5] = n \cdot p_5 = 500 \cdot 0.16 = 80$$
#
# This implies that in a random sample of 500, we expect around 80 people to be aged 65 and above, based on the population proportions. The multinomial probability formula allows us to calculate the probability of getting a specific distribution (like 100, 200, 200) across different age groups in the sample.
#
#
# ### Task 2 Answers:
# #### Question 1:
#
# The probability distribution of the experiment can be derived as follows:
#
# Since each trial results in either success ($S$) or failure ($F$), and the trials are independent, the probability of observing $y$ successes in $n$ trials follows a binomial distribution.
#
# The probability of observing exactly $y$ successes in $n$ trials is given by the binomial probability formula:
#
# $$[ P(Y=y) = \binom{n}{y} p^y q^{n-y} ]$$
#
# where:
# - $p$ is the probability of success on a single trial.
# - $q = (1 - p)$ is the probability of failure on a single trial.
# - $n$ is the total number of trials.
# - $y$ is the number of successes observed.
#
# This formula represents the probability distribution of the experiment.
#
# #### Question 2:
#
# To show that the expectation of this probability distribution is $E[y] = \sum y \cdot P(y) = np$:
#
# The expectation, $E[y]$, of a binomial distribution is given by the formula:
#
# $$[ E[y] = \sum_{y=0}^{n} y \cdot P(Y=y) ]$$
#
# Substituting the binomial probability formula, we get:
#
# $$[ E[y] = \sum_{y=0}^{n} y \cdot \binom{n}{y} p^y q^{n-y} ]$$
#
# This sum simplifies to $ np $, which proves that $E[y] = np$.
#
# #### Question 3:
#
# Given the experiment setup where the medication is worthless, the probability of recovery remains at 30%. We are interested in the probability of at least 9 out of 10 people recovering. Let $( Y $) be the number of recoveries.
#
# We need to find $$( P(Y \geq 9) )$$, which is:
#
# $$[ P(Y \geq 9) = P(Y = 9) + P(Y = 10) ]$$
#
# First, compute $$( P(Y = 9) )$$ and $$( P(Y = 10) )$$:
#
# $$[ P(Y = 9) = \binom{10}{9} (0.3)^9 (0.7)^1 = 10 \cdot (0.3)^9 \cdot (0.7) ]$$
# $$[ P(Y = 10) = \binom{10}{10} (0.3)^{10} (0.7)^0 = 1 \cdot (0.3)^{10} ]$$
#
# Calculate each term:
#
# $$[ P(Y = 9) = 10 \cdot (0.3)^9 \cdot 0.7 \approx 10 \cdot 0.000019683 \cdot 0.7 \approx 0.00013778 ]$$
# $$[ P(Y = 10) = (0.3)^{10} \approx 0.0000059049 ]$$
#
# Thus:
#
# $$[ P(Y \geq 9) = 0.00013778 + 0.0000059049 \approx 0.00014368 ]$$
#
# #### Question 4:
#
# The lot contains 5000 fuses with 5% defectives, so $( p = 0.05 )$. We test 5 fuses, so $( n = 5 )$.
#
# Let $( Y )$ be the number of defective fuses in the sample. We need $( P(Y \geq 1) )$, which can be found using the complement rule:
#
# $$[ P(Y \geq 1) = 1 - P(Y = 0) ]$$
#
# First, compute $( P(Y = 0) )$:
#
# $$[ P(Y = 0) = \binom{5}{0} (0.05)^0 (0.95)^5 = (0.95)^5 ]$$
#
# Calculate:
#
# $$[ (0.95)^5 \approx 0.77378 ]$$
#
# Therefore:
#
# $$[ P(Y \geq 1) = 1 - 0.77378 \approx 0.22622 ]$$
#
# So, the probability of observing at least one defective fuse in a sample of 5 is approximately $( 0.22622 )$ or 22.62%.
#
# ### Task 3 Answers:
# #### Question 1:
#
# For a Poisson random variable $(Y)$ with parameter $(\lambda)$, the expected value (mean) $(E[Y])$ can be derived from the definition of the Poisson distribution:
#
# $$[ p(y) = \frac{\lambda^y}{y!} e^{-\lambda}, \quad y = 0, 1, 2, \ldots ]$$
#
# To find the expected value $(E[Y]$), we use the definition of expectation:
#
# We will derive the expected value (mean) $E[Y]$ of a Poisson random variable $Y$ with parameter $\lambda$.
#
# **Poisson Probability Mass Function:**
#
# The Poisson distribution describes the probability of getting a specific number of events (e.g., successes) in a fixed interval. The probability mass function (PMF) defines the probability $p(y)$ of each possible outcome ($y$):
#
# \begin{equation}
# p(y) = \frac{\lambda^y}{y!} e^{-\lambda}, \quad y = 0, 1, 2, \ldots
# \end{equation}
#
# where:
#
# * $y$ is the number of events (e.g., successes)
# * $\lambda$ is the parameter of the distribution
# * $e$ is the mathematical constant (approximately 2.718)
#
# **Expected Value Formula:**
#
# The expected value, denoted by $E[Y]$, represents the average outcome we expect to see over many trials from this distribution. It's calculated by summing the product of each possible outcome ($y$) and its corresponding probability ($p(y)$):
#
# \begin{equation}
# E[Y] = \sum_{y=0}^{\infty} y \cdot p(y)
# \end{equation}
#
# **Deriving the Expected Value:**
#
# We substitute the Poisson PMF into the expected value formula:
#
# \begin{equation}
# E[Y] = \sum_{y=0}^{\infty} y \cdot \frac{\lambda^y}{y!} e^{-\lambda}
# \end{equation}
#
# To simplify the summation, we can rewrite $(y \cdot \frac{\lambda^y}{y!})$ as $(\lambda \cdot \frac{\lambda^{y-1}}{(y-1)!})$. This allows us to shift the index in the sum. Let's also substitute $(z = y - 1)$ for a new index variable.
#
# These transformations lead to:
#
# \begin{align*}
# E[Y] &= \sum_{y=0}^{\infty} y \cdot \frac{\lambda^y}{y!} e^{-\lambda} \\
# &= \sum_{y=0}^{\infty} \lambda \cdot \frac{\lambda^{y-1}}{(y-1)!} e^{-\lambda} \\
# &= \lambda e^{-\lambda} \sum_{y=1}^{\infty} \frac{\lambda^{y-1}}{(y-1)!} \\
# &= \lambda e^{-\lambda} \sum_{z=0}^{\infty} \frac{\lambda^z}{z!}
# {\text{Substitute } z = y - 1}
# \end{align*}
#
# **Recognizing the Summation:**
#
# The resulting summation $(\sum_{z=0}^{\infty} \frac{\lambda^z}{z!})$ is actually the Taylor series expansion of the mathematical constant $e$ raised to the power of $\lambda$ (denoted by $e^{\lambda}$).
#
# **Conclusion:**
#
# Since the summation represents $e^{\lambda}$, we can substitute:
#
# \begin{equation}
# E[Y] = \lambda e^{-\lambda} \cdot e^{\lambda} = \lambda
# \end{equation}
#
# Therefore, the expected value of a Poisson random variable with parameter $\lambda$ is simply $\lambda$ itself.
#
#
#
#
# #### Question 2:
#
# In this problem, we are given that the mean density of seedlings is $(\lambda = 5)$ seedlings per square yard. A forester randomly locates ten 1-square-yard sampling regions. Our objective is to find the probability that none of these regions will contain seedlings.
#
# Since the presence of seedlings in different regions is independent, we can model the number of seedlings in each 1-square-yard region as a Poisson random variable with $(\lambda = 5)$.
#
#
# The probability of finding zero seedlings in a single region can be calculated using the Poisson probability mass function (PMF):
#
# $$P(Y = 0) = \frac{\lambda^0}{0!} e^{-\lambda} = e^{-\lambda}$$
#
# In this case, $\lambda = 5$, so the probability of no seedlings in a single region is:
#
# $$P(Y = 0) = e^{-5}$$
#
# **Probability of No Seedlings (All Regions):**
#
# Since we have ten independent regions, and we're interested in the probability that none of them have seedlings, we consider the probability for a single region (no seedlings) raised to the power of ten (number of regions).
#
# This gives us the probability that none of the ten regions contain seedlings:
#
# $$P(\text{none of the regions contain seedlings}) = (e^{-5})^{10} = e^{-50}$$
#
# **Conclusion:**
#
# Therefore, the probability of finding no seedlings in any of the ten 1-square-yard sampling regions is:
#
# $$\boxed{e^{-50}}$$
